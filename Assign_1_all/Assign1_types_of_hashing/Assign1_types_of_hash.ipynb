# %%
import hashlib

# Simple hash function
def get_hash(data):
    return hashlib.sha256(data.encode()).hexdigest()


# Read file data
def read_file(filename):
    file = open(filename, "r")
    data = file.read()
    file.close()
    return data


# 1. Independent Hashing
def independent_hashing():
    print("\nIndependent Hashing")
    d1 = read_file("file1.txt")
    d2 = read_file("file2.txt")
    print(get_hash(d1))
    print(get_hash(d2))


# 2. Repeated Hashing
def repeated_hashing():
    print("\nRepeated Hashing")
    data = read_file("file1.txt")
    h1 = get_hash(data)
    h2 = get_hash(h1)
    print(h2)


# 3. Combined Hashing
def combined_hashing():
    print("\nCombined Hashing")
    d1 = read_file("file1.txt")
    d2 = read_file("file2.txt")
    combined = d1 + d2
    print(get_hash(combined))


# 4. Sequential Hashing
def sequential_hashing():
    print("\nSequential Hashing")
    d1 = read_file("file1.txt")
    d2 = read_file("file2.txt")

    h1 = get_hash(d1 + "0")
    h2 = get_hash(d2 + h1)

    print(h1)
    print(h2)


# 5. Hierarchical Hashing
def hierarchical_hashing():
    print("\nHierarchical Hashing")
    d1 = read_file("file1.txt")
    d2 = read_file("file2.txt")

    h1 = get_hash(d1)
    h2 = get_hash(d2)

    root = get_hash(h1 + h2)
    print(root)


# Main
independent_hashing()
repeated_hashing()
combined_hashing()
sequential_hashing()
hierarchical_hashing()
# Out:
# Independent Hashing
# c30b85b6f7109d004e162ebfa6f94634c11552edd88cde8692184d45582c59d4
# c37c035748bb34cbfe8842c86af1a2304111bffc1b207ccfaf6766318a63939d
#
# Repeated Hashing
# e1a6e2b6214ff9745afefd61235806abb6cd815a658beaf398cbca0777570e1f
#
# Combined Hashing
# 72ce2a509e92639ee60b52876bc60a1a173c43465a75911ea06b6d4fed3809f7
#
# Sequential Hashing
# ab1c1fa07c8345b9e9071c38a4e783deaac0eac45ea2f0bd6f7a79054e2a6e86
# 9a26ec9b706528576a92893d605f357934b3880063bd03672df33b4ef7f12de1
#
# Hierarchical Hashing
# f287413fa53987f07e46feecb27527dd1aff0a78c7e1da341e3c80ce2e56d88a
